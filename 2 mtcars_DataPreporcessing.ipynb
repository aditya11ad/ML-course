# %% [markdown]
# ## Data Preprocessing
# #### Mtcars, an automobile company in Chambersburg, United States, has recorded the production of its cars within a dataset. The company is coming up with a new model based on the feedback given by its customers. It has to explore the current dataset to derive further insights from it.
#
# ## explore for dimensionality, and type and average value of the horsepower across all the cars. Also, identify a few of mostly correlated features, which would help in modification.

# %% [markdown]
# ***

# %% [markdown]
# ### Data Exploration:

# %%
import pandas as pd
df=pd.read_csv('mtcars.csv')
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.shape
# Out:
# (32, 12)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
df['model'].dtype
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df['hp'].mean()
# Out:
# 146.6875

# %%
df['hp'].median()
# Out:
# 123.0

# %%
df['hp'].mode()
# Out:
# 0    110
# 1    175
# 2    180
# dtype: int64

# %%
correlations=df.corr()
correlations
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(correlations)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***

# %% [markdown]
# ## Data Wrangling:

# %% [markdown]
# ### Check for missing values and outliers within the horsepower column and remove them.

# %%
df.isna().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
df.isna().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %% [markdown]
# #### if any missing value
# missing vaues substitution

# %%
import numpy as np

# %%
 #df['col']=df['col'].fillna(df['col'].mean())

#or

#df=df.fillna(df.mean())

#or

#from sklearn.impute import SimpleImputer
#imp=SimpleImputer(missing_values=np.nan, strategy="most_frequent")
#df=imp.fit_transform(df)

# %% [markdown]
# ***
# #### oulier in HP

# %%
#Detecting Outlier
df.boxplot(['hp'])
# Out:
# <AxesSubplot:>

# %%
#Removing Outlier
filt=df['hp']<280
df_n=df[filt]
df_n
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# ***

# %% [markdown]
# #### All oulier in Dataset

# %%
#taking numeric columns
df1=df.iloc[:,1:]
df1.shape
# Out:
# (32, 11)

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
for column in df1:
    plt.figure()
    sns.boxplot(df1[column])   #or #df1.boxplot([column])
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
filter=(df1['hp']<280) & (df1['wt']<4.3) & (df1['qsec']<21) & (df1['carb']<6)
filter
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29    False
# 30    False
# 31     True
# dtype: bool

# %%
df1=df1[filter]
df1=df1.reset_index(drop=True)
df1
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 9   17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 10  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 11  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 12  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# ...

# %%
df1.shape
# Out:
# (26, 11)

# %%
# import matplotlib.pyplot as plt

for c in df1:
    plt.figure()
    sns.boxplot(df1[c])   #or #df1.boxplot([column])
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\adity\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# ***
# # Groupby:

# %%
df.groupby('gear').groups
# Out:
# {3: [3, 4, 5, 6, 11, 12, 13, 14, 15, 16, 20, 21, 22, 23, 24], 4: [0, 1, 2, 7, 8, 9, 10, 17, 18, 19, 25, 31], 5: [26, 27, 28, 29, 30]}

# %%
df.groupby('cyl').groups
# Out:
# {4: [2, 7, 8, 17, 18, 19, 20, 25, 26, 27, 31], 6: [0, 1, 3, 5, 9, 10, 29], 8: [4, 6, 11, 12, 13, 14, 15, 16, 21, 22, 23, 24, 28, 30]}

# %%
t=df.groupby('cyl')

# %%
t.get_group(4)
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 26   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 2      1
# 7      2
# 8      2
# 17     1
# ...

# %%
df.groupby(['gear','cyl']).groups
# Out:
# {(3, 4): [20], (3, 6): [3, 5], (3, 8): [4, 6, 11, 12, 13, 14, 15, 16, 21, 22, 23, 24], (4, 4): [2, 7, 8, 17, 18, 19, 25, 31], (4, 6): [0, 1, 9, 10], (5, 4): [26, 27], (5, 6): [29], (5, 8): [28, 30]}

# %%
df.groupby(['cyl','gear']).groups
# Out:
# {(4, 3): [20], (4, 4): [2, 7, 8, 17, 18, 19, 25, 31], (4, 5): [26, 27], (6, 3): [3, 5], (6, 4): [0, 1, 9, 10], (6, 5): [29], (8, 3): [4, 6, 11, 12, 13, 14, 15, 16, 21, 22, 23, 24], (8, 5): [28, 30]}

# %%
df.groupby('cyl')['hp'].mean()
# Out:
# cyl
# 4     82.636364
# 6    122.285714
# 8    209.214286
# Name: hp, dtype: float64

# %%
df2 = t.get_group(4)
df2
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 26   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 2      1
# 7      2
# 8      2
# 17     1
# ...

# %%
df2.reset_index(drop=True)
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 1        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 2         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 3         Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 4      Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 5   Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 6    Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 7        Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 8    Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 9     Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 10      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 0      1
# 1      2
# 2      2
# 3      1
# ...
